# %%
import os
import re
from collections import Counter

import anndata
import scanpy as sc
import numpy as np
import pandas as pd

import anndata2ri

# %%
# Activate the anndata2ri conversion between SingleCellExperiment and AnnData
anndata2ri.activate()

#Loading the rpy2 extension enables cell magic to be used
#This runs R code in jupyter notebook cells
# %load_ext rpy2.ipython

# %%
# input/output filepaths
rds_fp = '/home/estorrs/data/single_cell_classification/tumor/BR/scRNA/brca_with_immune.rds'
output_fp = '/home/estorrs/data/single_cell_classification/tumor/BR/scRNA/brca_with_immune_v2.h5ad'

# %%
# %%R -i rds_fp
# suppressPackageStartupMessages(library(Seurat))
#
# final = readRDS(file = rds_fp)

# %%
# %%R -o metadata -o counts -o sctransform -o sctransform_genes -o genes -o umap
# # add the active idents to the metadata
# final = AddMetaData(final, unname(final@active.ident), col.name = 'active.ident')
#
# # grab metadata
# metadata = final@meta.data
#
# # grab umap embeddings
# umap = Embeddings(final[["umap"]])
#
# # grab gene names
# genes = rownames(GetAssayData(object = final, slot = "counts", assay = "RNA"))
#
# # get raw counts
# counts = final@assays$RNA@counts
#
# # get sctransform genes and output
# sctransform_genes = rownames(GetAssayData(object = final, slot = "data", assay = "SCT"))
# sctransform = final@assays$SCT@data

# %%
counts.shape, sctransform.shape
# Out:
# ((33538, 98564), (27131, 98564))

# %%
metadata
# Out:
#                                                  orig.ident  nCount_RNA  \
# _HT062B1_S1PA_AAACCCACACAAATGA-1  TWCE-HT062B1-S1PAA1A1Z1B1      4837.0
# _HT062B1_S1PA_AAACCCAGTGCTCCGA-1  TWCE-HT062B1-S1PAA1A1Z1B1      6400.0
# _HT062B1_S1PA_AAACCCATCGGAATTC-1  TWCE-HT062B1-S1PAA1A1Z1B1     10255.0
# _HT062B1_S1PA_AAACGAACAGCTAACT-1  TWCE-HT062B1-S1PAA1A1Z1B1      1433.0
# _HT062B1_S1PA_AAACGAAGTAGGGAGG-1  TWCE-HT062B1-S1PAA1A1Z1B1      2256.0
# ...                                                     ...         ...
# _HT171B1_BC2_TTTGTTGCACCAGACC-1            TWCE-HT171B1-BC2      4717.0
# _HT171B1_BC2_TTTGTTGCACGTACTA-1            TWCE-HT171B1-BC2      4627.0
# _HT171B1_BC2_TTTGTTGTCCCAAGCG-1            TWCE-HT171B1-BC2      3236.0
# _HT171B1_BC2_TTTGTTGTCCTCACCA-1            TWCE-HT171B1-BC2     13163.0
# _HT171B1_BC2_TTTGTTGTCTCCATAT-1            TWCE-HT171B1-BC2      2649.0
#
#                                   nFeature_RNA  percent.mito  nCount_SCT  \
# _HT062B1_S1PA_AAACCCACACAAATGA-1          1378      0.043829      4154.0
# _HT062B1_S1PA_AAACCCAGTGCTCCGA-1          2369      0.061562      4515.0
# _HT062B1_S1PA_AAACCCATCGGAATTC-1          2945      0.042321      4558.0
# _HT062B1_S1PA_AAACGAACAGCTAACT-1           751      0.073273      3072.0
# _HT062B1_S1PA_AAACGAAGTAGGGAGG-1           934      0.050089      3281.0
# ...                                        ...           ...         ...
# _HT171B1_BC2_TTTGTTGCACCAGACC-1           1660      0.063600      4178.0
# _HT171B1_BC2_TTTGTTGCACGTACTA-1           1441      0.014048      4117.0
# _HT171B1_BC2_TTTGTTGTCCCAAGCG-1           1392      0.051916      3482.0
# _HT171B1_BC2_TTTGTTGTCCTCACCA-1           4124      0.036162      3946.0
# _HT171B1_BC2_TTTGTTGTCTCCATAT-1           1001      0.047943      3409.0
#
#                                   nFeature_SCT SCT_snn_res.0.5  \
# _HT062B1_S1PA_AAACCCACACAAATGA-1          1378               2
# _HT062B1_S1PA_AAACCCAGTGCTCCGA-1          2344               4
# _HT062B1_S1PA_AAACCCATCGGAATTC-1          1978              10
# _HT062B1_S1PA_AAACGAACAGCTAACT-1           801              13
# _HT062B1_S1PA_AAACGAAGTAGGGAGG-1           934               2
# ...                                        ...             ...
# _HT171B1_BC2_TTTGTTGCACCAGACC-1           1660               8
# _HT171B1_BC2_TTTGTTGCACGTACTA-1           1441               1
# _HT171B1_BC2_TTTGTTGTCCCAAGCG-1           1392               8
# _HT171B1_BC2_TTTGTTGTCCTCACCA-1           1808               7
# _HT171B1_BC2_TTTGTTGTCTCCATAT-1           1001               0
#
#                                  seurat_clusters   sample tissue_type  \
# _HT062B1_S1PA_AAACCCACACAAATGA-1               2  HT062B1       tumor
# _HT062B1_S1PA_AAACCCAGTGCTCCGA-1               4  HT062B1       tumor
# _HT062B1_S1PA_AAACCCATCGGAATTC-1              10  HT062B1       tumor
# _HT062B1_S1PA_AAACGAACAGCTAACT-1              13  HT062B1       tumor
# _HT062B1_S1PA_AAACGAAGTAGGGAGG-1               2  HT062B1       tumor
# ...                                          ...      ...         ...
# _HT171B1_BC2_TTTGTTGCACCAGACC-1                8  HT171B1       tumor
# _HT171B1_BC2_TTTGTTGCACGTACTA-1                1  HT171B1       tumor
# _HT171B1_BC2_TTTGTTGTCCCAAGCG-1                8  HT171B1       tumor
# _HT171B1_BC2_TTTGTTGTCCTCACCA-1                7  HT171B1       tumor
# _HT171B1_BC2_TTTGTTGTCTCCATAT-1                0  HT171B1       tumor
#
#                                     cell_type        cell_type_specific  \
# _HT062B1_S1PA_AAACCCACACAAATGA-1        CD8_T                   CD8_CTL
# _HT062B1_S1PA_AAACCCAGTGCTCCGA-1  Endothelial               Endothelial
# _HT062B1_S1PA_AAACCCATCGGAATTC-1          CAF                      mCAF
# _HT062B1_S1PA_AAACGAACAGCTAACT-1        Tumor                     Tumor
# _HT062B1_S1PA_AAACGAAGTAGGGAGG-1        CD8_T  CD8_T preexhausted GZMK+
# ...                                       ...                       ...
# _HT171B1_BC2_TTTGTTGCACCAGACC-1         CD4_T           CD4_T exhausted
# _HT171B1_BC2_TTTGTTGCACGTACTA-1         Tumor                     Tumor
# _HT171B1_BC2_TTTGTTGTCCCAAGCG-1         CD8_T           CD8_T exhausted
# _HT171B1_BC2_TTTGTTGTCCTCACCA-1    Mono_Macro                Mono_Macro
# _HT171B1_BC2_TTTGTTGTCTCCATAT-1         CD4_T           CD4_T activated
#
#                                       Piece_ID Clinical_Subtype  \
# _HT062B1_S1PA_AAACCCACACAAATGA-1  HT062B1_S1PA             TNBC
# _HT062B1_S1PA_AAACCCAGTGCTCCGA-1  HT062B1_S1PA             TNBC
# _HT062B1_S1PA_AAACCCATCGGAATTC-1  HT062B1_S1PA             TNBC
# _HT062B1_S1PA_AAACGAACAGCTAACT-1  HT062B1_S1PA             TNBC
# _HT062B1_S1PA_AAACGAAGTAGGGAGG-1  HT062B1_S1PA             TNBC
# ...                                        ...              ...
# _HT171B1_BC2_TTTGTTGCACCAGACC-1   HT171B1_S1H8             TNBC
# _HT171B1_BC2_TTTGTTGCACGTACTA-1   HT171B1_S1H8             TNBC
# _HT171B1_BC2_TTTGTTGTCCCAAGCG-1   HT171B1_S1H8             TNBC
# _HT171B1_BC2_TTTGTTGTCCTCACCA-1   HT171B1_S1H8             TNBC
# _HT171B1_BC2_TTTGTTGTCTCCATAT-1   HT171B1_S1H8             TNBC
#
#                                   doublet_score  predicted_doublet  \
# _HT062B1_S1PA_AAACCCACACAAATGA-1       0.036018                  0
# _HT062B1_S1PA_AAACCCAGTGCTCCGA-1       0.105210                  0
# _HT062B1_S1PA_AAACCCATCGGAATTC-1       0.051376                  0
# _HT062B1_S1PA_AAACGAACAGCTAACT-1       0.013000                  0
# _HT062B1_S1PA_AAACGAAGTAGGGAGG-1       0.027729                  0
# ...                                         ...                ...
# _HT171B1_BC2_TTTGTTGCACCAGACC-1        0.104260                  0
# _HT171B1_BC2_TTTGTTGCACGTACTA-1        0.034114                  0
# _HT171B1_BC2_TTTGTTGTCCCAAGCG-1        0.027347                  0
# _HT171B1_BC2_TTTGTTGTCCTCACCA-1        0.233279                  0
# _HT171B1_BC2_TTTGTTGTCTCCATAT-1        0.024146                  0
#
#                                  Composite_PAM50              active.ident
# _HT062B1_S1PA_AAACCCACACAAATGA-1            Her2                   CD8_CTL
# _HT062B1_S1PA_AAACCCAGTGCTCCGA-1            Her2               Endothelial
# _HT062B1_S1PA_AAACCCATCGGAATTC-1            Her2                      mCAF
# _HT062B1_S1PA_AAACGAACAGCTAACT-1            Her2                     Tumor
# _HT062B1_S1PA_AAACGAAGTAGGGAGG-1            Her2  CD8_T preexhausted GZMK+
# ...                                          ...                       ...
# _HT171B1_BC2_TTTGTTGCACCAGACC-1            Basal           CD4_T exhausted
# _HT171B1_BC2_TTTGTTGCACGTACTA-1            Basal                     Tumor
# _HT171B1_BC2_TTTGTTGTCCCAAGCG-1            Basal           CD8_T exhausted
# _HT171B1_BC2_TTTGTTGTCCTCACCA-1            Basal                Mono_Macro
# _HT171B1_BC2_TTTGTTGTCTCCATAT-1            Basal           CD4_T activated
#
# [98564 rows x 18 columns]

# %%
# create new anndata object with sctransform normalized counts
adata = anndata.AnnData(X=counts.transpose(), obs=metadata,)
adata.var.index = genes

# filter to sctransform genes and put raw counts into different layer to make room for sctransform data
# comment out these 3 lines if you don't need the sctransform expression and are only interested in raw counts
adata = adata[:, sctransform_genes]
adata.layers['counts'] = adata.X.copy()
adata.X = sctransform.transpose()

# carry over umap and is_highly_variable from seurat
adata.obsm['X_umap'] = np.asarray(umap)

adata
# Out:
# AnnData object with n_obs × n_vars = 98564 × 27131
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.mito', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.5', 'seurat_clusters', 'sample', 'tissue_type', 'cell_type', 'cell_type_specific', 'Piece_ID', 'Clinical_Subtype', 'doublet_score', 'predicted_doublet', 'Composite_PAM50', 'active.ident'
#     obsm: 'X_umap'
#     layers: 'counts'

# %%
# some versions of scanpy save the .h5ad weird so making sure columns are unicode strings before saving
adata.obs.columns = adata.obs.columns.astype(str)
adata.var.columns = adata.var.columns.astype(str)
adata.write_h5ad(output_fp)
# Out:
# ... storing 'orig.ident' as categorical
# ... storing 'sample' as categorical
# ... storing 'tissue_type' as categorical
# ... storing 'Piece_ID' as categorical
# ... storing 'Clinical_Subtype' as categorical
# ... storing 'Composite_PAM50' as categorical
